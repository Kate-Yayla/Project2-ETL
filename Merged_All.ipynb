# %%
import pandas as pd
from sqlalchemy import create_engine
import json
import os

# %%
cleanedUSdata_csvfile = "Resources\cleanedUSdata.csv"
cleanedUSdata = pd.read_csv(cleanedUSdata_csvfile)
cleanedUSdata.head()
# Out:
#       video_id trending_date  \
# 0  2kyS6SvSYSE      17.14.11
# 1  1ZAPwfrtAFY      17.14.11
# 2  5qpjK5DgCt4      17.14.11
# 3  puqaWrEC7tY      17.14.11
# 4  d380meD0W0M      17.14.11
#
#                                          video_title          channel_title  \
# 0                 WE WANT TO TALK ABOUT OUR MARRIAGE           CaseyNeistat
# 1  The Trump Presidency: Last Week Tonight with J...        LastWeekTonight
# 2  Racist Superman | Rudy Mancuso, King Bach & Le...           Rudy Mancuso
# 3                   Nickelback Lyrics: Real or Fake?  Good Mythical Morning
# 4                           I Dare You: GOING BALD!?               nigahiga
#
#    category_id                                               tags    views  \
# 0           22                                    SHANtell martin   748374
# 1           24  last week tonight trump presidency|"last week ...  2418783
# 2           23  racist superman|"rudy"|"mancuso"|"king"|"bach"...  3191434
# ...

# %%
cleanedMXdata_csvfile = "Resources\cleanedMXdata.csv"
cleanedMXdata = pd.read_csv(cleanedMXdata_csvfile)
cleanedMXdata.head()
# Out:
#       video_id trending_date  \
# 0  SbOwzAl9ZfQ      17.14.11
# 1  klOV6Xh-DnI      17.14.11
# 2  6L2ZF7Qzsbk      17.14.11
# 3  hcY52MFWMDM      17.14.11
# 4  _OXDcGPVAa4      17.14.11
#
#                                          video_title  \
# 0                     CapÃ­tulo 12 | MasterChef 2017
# 1  ALEXA EX-INTEGRANTE DEL GRUPO TIMBIRICHE RENUN...
# 2           LOUIS CKAGÃ - EL PULSO DE LA REPÃBLICA
# 3   Sismo de 6.7 sacude Costa Rica 12 Noviembre 2017
# 4           DOG HACKS | MUSAS LESSLIE LOS POLINESIOS
#
#                channel_title  category_id  \
# 0            MasterChef 2017           24
# 1   Micky Contreras Martinez           22
# 2  El Pulso De La RepÃºblica           25
# 3                   Casanare           25
# 4                      Musas           26
#
#                                                 tags   views  likes  dislikes  \
# 0  MasterChef Junior 2017|"TV Azteca"|"recetas"|"...  310130   4182       361
# ...

# %%
cleanedCAdata_csvfile = "Resources\cleanedCAdata.csv"
cleanedCAdata = pd.read_csv(cleanedCAdata_csvfile)
cleanedCAdata.head()
# Out:
#       video_id trending_date  \
# 0  n1WpP7iowLc      17.14.11
# 1  0dBIkQ4Mz1M      17.14.11
# 2  5qpjK5DgCt4      17.14.11
# 3  d380meD0W0M      17.14.11
# 4  2Vv-BfVoq4g      17.14.11
#
#                                          video_title channel_title  \
# 0         Eminem - Walk On Water (Audio) ft. Beyoncé    EminemVEVO
# 1                      PLUSH - Bad Unboxing Fan Mail     iDubbbzTV
# 2  Racist Superman | Rudy Mancuso, King Bach & Le...  Rudy Mancuso
# 3                           I Dare You: GOING BALD!?      nigahiga
# 4        Ed Sheeran - Perfect (Official Music Video)    Ed Sheeran
#
#    category_id                                               tags     views  \
# 0           10  Eminem|"Walk"|"On"|"Water"|"Aftermath/Shady/In...  17158579
# 1           23  plush|"bad unboxing"|"unboxing"|"fan mail"|"id...   1014651
# 2           23  racist superman|"rudy"|"mancuso"|"king"|"bach"...   3191434
# ...

# %%
cleanedCAdata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40881 entries, 0 to 40880
# Data columns (total 18 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   video_id                40881 non-null  object
#  1   trending_date           40881 non-null  object
#  2   video_title             40881 non-null  object
#  3   channel_title           40881 non-null  object
#  4   category_id             40881 non-null  int64
#  5   tags                    40881 non-null  object
#  6   views                   40881 non-null  int64
#  7   likes                   40881 non-null  int64
#  8   dislikes                40881 non-null  int64
#  9   comment_count           40881 non-null  int64
#  10  comments_disabled       40881 non-null  bool
#  11  ratings_disabled        40881 non-null  bool
#  12  video_error_or_removed  40881 non-null  bool
#  13  kind                    40807 non-null  object
# ...

# %%
cleanedUSdata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40949 entries, 0 to 40948
# Data columns (total 18 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   video_id                40949 non-null  object
#  1   trending_date           40949 non-null  object
#  2   video_title             40949 non-null  object
#  3   channel_title           40949 non-null  object
#  4   category_id             40949 non-null  int64
#  5   tags                    40949 non-null  object
#  6   views                   40949 non-null  int64
#  7   likes                   40949 non-null  int64
#  8   dislikes                40949 non-null  int64
#  9   comment_count           40949 non-null  int64
#  10  comments_disabled       40949 non-null  bool
#  11  ratings_disabled        40949 non-null  bool
#  12  video_error_or_removed  40949 non-null  bool
#  13  kind                    40949 non-null  object
# ...

# %%
cleanedMXdata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40451 entries, 0 to 40450
# Data columns (total 18 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   video_id                40451 non-null  object
#  1   trending_date           40451 non-null  object
#  2   video_title             40451 non-null  object
#  3   channel_title           40451 non-null  object
#  4   category_id             40451 non-null  int64
#  5   tags                    40451 non-null  object
#  6   views                   40451 non-null  int64
#  7   likes                   40451 non-null  int64
#  8   dislikes                40451 non-null  int64
#  9   comment_count           40451 non-null  int64
#  10  comments_disabled       40451 non-null  bool
#  11  ratings_disabled        40451 non-null  bool
#  12  video_error_or_removed  40451 non-null  bool
#  13  kind                    40199 non-null  object
# ...

# %%
smallcleanedUSdata = cleanedUSdata.head(100)
smallcleanedUSdata
# Out:
#        video_id trending_date  \
# 0   2kyS6SvSYSE      17.14.11
# 1   1ZAPwfrtAFY      17.14.11
# 2   5qpjK5DgCt4      17.14.11
# 3   puqaWrEC7tY      17.14.11
# 4   d380meD0W0M      17.14.11
# ..          ...           ...
# 95  e4FApt6z55c      17.14.11
# 96  2XK4omx9uMU      17.14.11
# 97  xfmipNU4Odc      17.14.11
# 98  jp9hK-jY6yY      17.14.11
# 99  RkHuWjiR-LM      17.14.11
#
#                                           video_title  \
# 0                  WE WANT TO TALK ABOUT OUR MARRIAGE
# 1   The Trump Presidency: Last Week Tonight with J...
# 2   Racist Superman | Rudy Mancuso, King Bach & Le...
# 3                    Nickelback Lyrics: Real or Fake?
# 4                            I Dare You: GOING BALD!?
# ..                                                ...
# 95   Kimbra - Top of the World (Official Music Video)
# 96  Camila Cabello COMPLETELY NAILS 'Finish The Ly...
# 97  Edna's registered owner thought she was dead f...
# ...

# %%
smallcleanedMXdata = cleanedMXdata.head(100)
smallcleanedMXdata
# Out:
#        video_id trending_date  \
# 0   SbOwzAl9ZfQ      17.14.11
# 1   klOV6Xh-DnI      17.14.11
# 2   6L2ZF7Qzsbk      17.14.11
# 3   hcY52MFWMDM      17.14.11
# 4   _OXDcGPVAa4      17.14.11
# ..          ...           ...
# 95  nC0TkydzQM4      17.14.11
# 96  LTiiX8hq4Sw      17.14.11
# 97  _GaoLGcZ8Wg      17.14.11
# 98  2-p6XmtKCVY      17.14.11
# 99  Yoa0Yqjedhk      17.14.11
#
#                                           video_title  \
# 0                      CapÃ­tulo 12 | MasterChef 2017
# 1   ALEXA EX-INTEGRANTE DEL GRUPO TIMBIRICHE RENUN...
# 2            LOUIS CKAGÃ - EL PULSO DE LA REPÃBLICA
# 3    Sismo de 6.7 sacude Costa Rica 12 Noviembre 2017
# 4            DOG HACKS | MUSAS LESSLIE LOS POLINESIOS
# ..                                                ...
# 95  Â¿QuÃ© tan Buena es COCO? - Platica con Spoile...
# 96                   Crema tonificante para el cuerpo
# 97  POR FIN!! DOS FICHAJES BOMBA PARA EL CRUZ AZUL...
# ...

# %%
smallcleanedCAdata = cleanedCAdata.head(100)
smallcleanedCAdata
# Out:
#        video_id trending_date  \
# 0   n1WpP7iowLc      17.14.11
# 1   0dBIkQ4Mz1M      17.14.11
# 2   5qpjK5DgCt4      17.14.11
# 3   d380meD0W0M      17.14.11
# 4   2Vv-BfVoq4g      17.14.11
# ..          ...           ...
# 95  zxuvr9tN924      17.14.11
# 96  dKBThyjj0J0      17.14.11
# 97  pQgPR2V6924      17.14.11
# 98  lHcXhBojpeQ      17.14.11
# 99  Yo84eqYwP98      17.14.11
#
#                                           video_title  \
# 0          Eminem - Walk On Water (Audio) ft. Beyoncé
# 1                       PLUSH - Bad Unboxing Fan Mail
# 2   Racist Superman | Rudy Mancuso, King Bach & Le...
# 3                            I Dare You: GOING BALD!?
# 4         Ed Sheeran - Perfect (Official Music Video)
# ..                                                ...
# 95       非诚勿扰 完整版 “小朱亚文”亮相《非诚勿扰》 孟非上演cosplay首秀 171111
# 96  'Helping People' Sneak Peek Ep. 805 | The Walk...
# 97  《文茜世界周報》美媒狂酸川普　對華貿易選前選後判若兩人2017.11.11|Sisy's W...
# ...

# %%
smallmerged_US_MX = pd.merge(smallcleanedUSdata,smallcleanedMXdata, on= "category_id")
smallmerged_US_MX
# Out:
#        video_id_x trending_date_x  \
# 0     2kyS6SvSYSE        17.14.11
# 1     2kyS6SvSYSE        17.14.11
# 2     2kyS6SvSYSE        17.14.11
# 3     2kyS6SvSYSE        17.14.11
# 4     2kyS6SvSYSE        17.14.11
# ...           ...             ...
# 1294  b4vTZx_AtHk        17.14.11
# 1295  b4vTZx_AtHk        17.14.11
# 1296  b4vTZx_AtHk        17.14.11
# 1297  U0hAC8O7RoI        17.14.11
# 1298  pjuPpVLXDQg        17.14.11
#
#                                           video_title_x channel_title_x  \
# 0                    WE WANT TO TALK ABOUT OUR MARRIAGE    CaseyNeistat
# 1                    WE WANT TO TALK ABOUT OUR MARRIAGE    CaseyNeistat
# 2                    WE WANT TO TALK ABOUT OUR MARRIAGE    CaseyNeistat
# 3                    WE WANT TO TALK ABOUT OUR MARRIAGE    CaseyNeistat
# 4                    WE WANT TO TALK ABOUT OUR MARRIAGE    CaseyNeistat
# ...                                                 ...             ...
# ...
